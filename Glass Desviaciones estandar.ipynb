# %% [markdown]
# # Estimación de la estabilidad estadística de las simulaciones del software Casino v2

# %%
import pyautogui # contienen funciones que automatizan los movimientos del puntero y de las entradas del teclado 
import time
import numpy as np
import matplotlib.pyplot as plt

# %%
espesores=[[440,520],[1000],[1600],[2180],[2750]]
#espesores=[espesores[-1]]
espesores
# Out:
# [[440, 520], [1000], [1600], [2180], [2750]]

# %%
espesores
# Out:
# [[440, 520], [1000], [1600], [2180], [2750]]

# %%
time.sleep(3)
tini=time.time()
name='Glass'
energy=10
e0=15
for listac in espesores:
    tt=0.01 #tiempo de respuesta de los comandos
    #listac = [120,400,720,900,1080]#15#[20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 280, 320, 360, 400, 440, 480, 520, 560, 600, 660, 720, 780, 840, 900, 960, 1020, 1080, 1140, 1200, 1280, 1360, 1440, 1520, 1600, 1680, 1760, 1840, 1920, 2000, 2100, 2200, 2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300, 3400, 3500, 3600, 3700, 3800, 3900, 4000, 4200, 4400, 4600, 4800, 5000]
    #cambiar energía 
    pyautogui.moveTo(272,56,duration=tt,tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    pyautogui.moveTo(578,270,duration=tt,tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    pyautogui.click()
    pyautogui.write(str(energy),interval=0.1)
    pyautogui.press('enter')
    for thickness in listac:
        for i in range(0,16):
            pyautogui.moveTo(243,54,duration=tt,tween=pyautogui.easeInOutQuad)
            pyautogui.click()
            pyautogui.moveTo(776,177,duration=tt,tween=pyautogui.easeInOutQuad)
            pyautogui.click()
            pyautogui.write(str(thickness),interval=0.05)
            pyautogui.press('enter')
            pyautogui.press('enter')
            pyautogui.moveTo(15,30,duration=tt,tween=pyautogui.easeInOutQuad)
            pyautogui.click()
            pyautogui.moveTo(30,120,duration=tt,tween=pyautogui.easeInOutQuad)
            pyautogui.click()
            pyautogui.write(f'TiN_on_{name}_{energy}KV_{thickness}_nm_{i}',interval=0.05)
            pyautogui.press('enter')
        print(f'está listo el archivo .sim de {thickness}')
    energy = energy+5
tfini=time.time()
print(f'Done!, la ejecución tardó {tfini-tini} segundos')
# Out:
# está listo el archivo .sim de 440
# está listo el archivo .sim de 520
# está listo el archivo .sim de 1000
# está listo el archivo .sim de 1600
# está listo el archivo .sim de 2180
# está listo el archivo .sim de 2750
# Done!, la ejecución tardó 313.07264709472656 segundos

# %%
1280/60

# %%
import pyautogui
import time
import os 
import pandas as pd 
tiniT=time.time()

path='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Glass\\Estabilidad\\12Mar'
files=os.listdir(path)
#encuentra la ruta
files_cas = [f for f in files if f[-4:] == '.cas']
#toma solo los archivos terminados en .cas
daux={}
total=[]
for file in files_cas:
    newstr = ''.join((ch if ch in '0123456789-e' else ' ') for ch in file)#toma los numeros del nombre del archivo
    listOfNumbers = [int(i) for i in newstr.split()]#ubica los números dentro de un diccionario
    daux['name']=file
    daux['thickness']=listOfNumbers[1]
    daux['energy'] = listOfNumbers[0]
    daux['number'] = listOfNumbers[2]
    total.append(daux)
    daux={}
from operator import itemgetter
total.sort(key=itemgetter('thickness')) # ordena los diccionarios de total de menor a mayor thickness
##ABRIR CASINO_v2
pyautogui.FAILSAFE = True # si se desplaza el puntero a la esquina superior izquierda el programa deja de ejecutarse
for index in total: 
    name=index['name']
    thickness=index['thickness']
    energy = index['energy']
    number = index['number']
    tt=0.1
    time.sleep(2)#tiempo de espera mientras se abre la simulacion .cas #crítico
    #movimiento del puntero dentro del software ´para abrir 
    pyautogui.moveTo(15,28, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    pyautogui.moveTo(15,73,duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    time.sleep(1)
    pyautogui.write(name)
    pyautogui.press('enter')
    print(f'el archivo {name} ha sido abierto!')
    t0=time.time()
    th=40
    x,y=8,80
    xs1=0
    ys1=0
    ys2=0
    time.sleep(2)# tiempo mientras se abre el archivo .cas
    
    xs1=37#distancia del
    ys1=51
    ys2=18#distancia entre carpeta y carpeta
    tt=0.1
    pyautogui.moveTo(x, y, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    pyautogui.move(0,ys1, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.move(xs1,0, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    ##export
    pyautogui.moveTo(48, 57, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.moveTo(218,57, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    pyautogui.write(f'TiN_on_SS_{energy}_KV_{thickness}_nm_time_{number}', interval=0.1*tt)
    pyautogui.press('enter')
    pyautogui.moveTo(x, y, duration=tt, tween=pyautogui.easeInOutQuad)
    pyautogui.click()
    pyautogui.moveTo(x, y+ys2, duration=tt, tween=pyautogui.easeInOutQuad)
    y=y+ys2
    x=x
    
    tf=time.time()
    delta=tf-t0
    print(delta)
    print(f'{name} Done!')
tfinT=time.time()
print(f'Los archivos .dat estan listos, la operación tardo {tfinT-tiniT} segundos, {(tfinT-tiniT)/60} minutos o {(tfinT-tiniT)/3600} horas.')
# Out:
# el archivo TiN_on_Glass_10KV_440_nm_0.cas ha sido abierto!
# 3.9154019355773926
# TiN_on_Glass_10KV_440_nm_0.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_1.cas ha sido abierto!
# 3.8880515098571777
# TiN_on_Glass_10KV_440_nm_1.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_10.cas ha sido abierto!
# 3.823982000350952
# TiN_on_Glass_10KV_440_nm_10.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_11.cas ha sido abierto!
# 3.9726309776306152
# TiN_on_Glass_10KV_440_nm_11.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_12.cas ha sido abierto!
# 3.864230155944824
# TiN_on_Glass_10KV_440_nm_12.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_13.cas ha sido abierto!
# 3.905349016189575
# TiN_on_Glass_10KV_440_nm_13.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_14.cas ha sido abierto!
# 3.969461679458618
# TiN_on_Glass_10KV_440_nm_14.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_15.cas ha sido abierto!
# 3.8797550201416016
# TiN_on_Glass_10KV_440_nm_15.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_2.cas ha sido abierto!
# 3.9055655002593994
# TiN_on_Glass_10KV_440_nm_2.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_3.cas ha sido abierto!
# 3.898730993270874
# TiN_on_Glass_10KV_440_nm_3.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_4.cas ha sido abierto!
# 3.8936212062835693
# TiN_on_Glass_10KV_440_nm_4.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_5.cas ha sido abierto!
# 3.8537542819976807
# TiN_on_Glass_10KV_440_nm_5.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_6.cas ha sido abierto!
# 3.8635993003845215
# TiN_on_Glass_10KV_440_nm_6.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_7.cas ha sido abierto!
# 3.922621965408325
# TiN_on_Glass_10KV_440_nm_7.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_8.cas ha sido abierto!
# 3.8862714767456055
# TiN_on_Glass_10KV_440_nm_8.cas Done!
# el archivo TiN_on_Glass_10KV_440_nm_9.cas ha sido abierto!
# 4.030314207077026
# TiN_on_Glass_10KV_440_nm_9.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_0.cas ha sido abierto!
# 3.8379499912261963
# TiN_on_Glass_10KV_520_nm_0.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_1.cas ha sido abierto!
# 3.8778438568115234
# TiN_on_Glass_10KV_520_nm_1.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_10.cas ha sido abierto!
# 3.862058401107788
# TiN_on_Glass_10KV_520_nm_10.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_11.cas ha sido abierto!
# 3.921321392059326
# TiN_on_Glass_10KV_520_nm_11.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_12.cas ha sido abierto!
# 4.0829551219940186
# TiN_on_Glass_10KV_520_nm_12.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_13.cas ha sido abierto!
# 3.918236494064331
# TiN_on_Glass_10KV_520_nm_13.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_14.cas ha sido abierto!
# 3.931504726409912
# TiN_on_Glass_10KV_520_nm_14.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_15.cas ha sido abierto!
# 3.851741313934326
# TiN_on_Glass_10KV_520_nm_15.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_2.cas ha sido abierto!
# 3.854501247406006
# TiN_on_Glass_10KV_520_nm_2.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_3.cas ha sido abierto!
# 4.050198078155518
# TiN_on_Glass_10KV_520_nm_3.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_4.cas ha sido abierto!
# 3.9127354621887207
# TiN_on_Glass_10KV_520_nm_4.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_5.cas ha sido abierto!
# 3.848618268966675
# TiN_on_Glass_10KV_520_nm_5.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_6.cas ha sido abierto!
# 3.810042142868042
# TiN_on_Glass_10KV_520_nm_6.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_7.cas ha sido abierto!
# 3.9123058319091797
# TiN_on_Glass_10KV_520_nm_7.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_8.cas ha sido abierto!
# 3.9392616748809814
# TiN_on_Glass_10KV_520_nm_8.cas Done!
# el archivo TiN_on_Glass_10KV_520_nm_9.cas ha sido abierto!
# 3.8997156620025635
# TiN_on_Glass_10KV_520_nm_9.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_0.cas ha sido abierto!
# 3.882033109664917
# TiN_on_Glass_15KV_1000_nm_0.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_1.cas ha sido abierto!
# 3.89791202545166
# TiN_on_Glass_15KV_1000_nm_1.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_10.cas ha sido abierto!
# 3.9140307903289795
# TiN_on_Glass_15KV_1000_nm_10.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_11.cas ha sido abierto!
# 3.921064853668213
# TiN_on_Glass_15KV_1000_nm_11.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_12.cas ha sido abierto!
# 3.963489055633545
# TiN_on_Glass_15KV_1000_nm_12.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_13.cas ha sido abierto!
# 3.9344635009765625
# TiN_on_Glass_15KV_1000_nm_13.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_14.cas ha sido abierto!
# 3.929421901702881
# TiN_on_Glass_15KV_1000_nm_14.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_15.cas ha sido abierto!
# 3.8781673908233643
# TiN_on_Glass_15KV_1000_nm_15.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_2.cas ha sido abierto!
# 3.9382376670837402
# TiN_on_Glass_15KV_1000_nm_2.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_3.cas ha sido abierto!
# 3.900437593460083
# TiN_on_Glass_15KV_1000_nm_3.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_4.cas ha sido abierto!
# 3.896045446395874
# TiN_on_Glass_15KV_1000_nm_4.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_5.cas ha sido abierto!
# 3.9469399452209473
# TiN_on_Glass_15KV_1000_nm_5.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_6.cas ha sido abierto!
# 3.890922784805298
# TiN_on_Glass_15KV_1000_nm_6.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_7.cas ha sido abierto!
# 3.919736862182617
# TiN_on_Glass_15KV_1000_nm_7.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_8.cas ha sido abierto!
# 4.135637044906616
# TiN_on_Glass_15KV_1000_nm_8.cas Done!
# el archivo TiN_on_Glass_15KV_1000_nm_9.cas ha sido abierto!
# 3.9229936599731445
# TiN_on_Glass_15KV_1000_nm_9.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_0.cas ha sido abierto!
# 3.8848936557769775
# TiN_on_Glass_20KV_1600_nm_0.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_1.cas ha sido abierto!
# 3.8740170001983643
# TiN_on_Glass_20KV_1600_nm_1.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_10.cas ha sido abierto!
# 3.934458017349243
# TiN_on_Glass_20KV_1600_nm_10.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_11.cas ha sido abierto!
# 4.325284242630005
# TiN_on_Glass_20KV_1600_nm_11.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_12.cas ha sido abierto!
# 3.966996431350708
# TiN_on_Glass_20KV_1600_nm_12.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_13.cas ha sido abierto!
# 3.901702404022217
# TiN_on_Glass_20KV_1600_nm_13.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_14.cas ha sido abierto!
# 3.9487876892089844
# TiN_on_Glass_20KV_1600_nm_14.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_15.cas ha sido abierto!
# 3.9715607166290283
# TiN_on_Glass_20KV_1600_nm_15.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_2.cas ha sido abierto!
# 4.151342153549194
# TiN_on_Glass_20KV_1600_nm_2.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_3.cas ha sido abierto!
# 3.896148204803467
# TiN_on_Glass_20KV_1600_nm_3.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_4.cas ha sido abierto!
# 3.9085159301757812
# TiN_on_Glass_20KV_1600_nm_4.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_5.cas ha sido abierto!
# 3.895075798034668
# TiN_on_Glass_20KV_1600_nm_5.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_6.cas ha sido abierto!
# 3.913200855255127
# TiN_on_Glass_20KV_1600_nm_6.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_7.cas ha sido abierto!
# 3.914790391921997
# TiN_on_Glass_20KV_1600_nm_7.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_8.cas ha sido abierto!
# 3.990021228790283
# TiN_on_Glass_20KV_1600_nm_8.cas Done!
# el archivo TiN_on_Glass_20KV_1600_nm_9.cas ha sido abierto!
# 3.942373752593994
# TiN_on_Glass_20KV_1600_nm_9.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_0.cas ha sido abierto!
# 3.8727285861968994
# TiN_on_Glass_25KV_2180_nm_0.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_1.cas ha sido abierto!
# 3.897164821624756
# TiN_on_Glass_25KV_2180_nm_1.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_10.cas ha sido abierto!
# 3.966576099395752
# TiN_on_Glass_25KV_2180_nm_10.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_11.cas ha sido abierto!
# 3.970587968826294
# TiN_on_Glass_25KV_2180_nm_11.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_12.cas ha sido abierto!
# 3.8839731216430664
# TiN_on_Glass_25KV_2180_nm_12.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_13.cas ha sido abierto!
# 3.8536360263824463
# TiN_on_Glass_25KV_2180_nm_13.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_14.cas ha sido abierto!
# 3.9308865070343018
# TiN_on_Glass_25KV_2180_nm_14.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_15.cas ha sido abierto!
# 3.879026174545288
# TiN_on_Glass_25KV_2180_nm_15.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_2.cas ha sido abierto!
# 3.9555747509002686
# TiN_on_Glass_25KV_2180_nm_2.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_3.cas ha sido abierto!
# 3.883385419845581
# TiN_on_Glass_25KV_2180_nm_3.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_4.cas ha sido abierto!
# 3.919992446899414
# TiN_on_Glass_25KV_2180_nm_4.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_5.cas ha sido abierto!
# 3.855325698852539
# TiN_on_Glass_25KV_2180_nm_5.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_6.cas ha sido abierto!
# 3.889159679412842
# TiN_on_Glass_25KV_2180_nm_6.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_7.cas ha sido abierto!
# 3.913444995880127
# TiN_on_Glass_25KV_2180_nm_7.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_8.cas ha sido abierto!
# 3.9128124713897705
# TiN_on_Glass_25KV_2180_nm_8.cas Done!
# el archivo TiN_on_Glass_25KV_2180_nm_9.cas ha sido abierto!
# 3.9199776649475098
# TiN_on_Glass_25KV_2180_nm_9.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_0.cas ha sido abierto!
# 3.8744163513183594
# TiN_on_Glass_30KV_2750_nm_0.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_1.cas ha sido abierto!
# 3.847580671310425
# TiN_on_Glass_30KV_2750_nm_1.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_10.cas ha sido abierto!
# 3.8660223484039307
# TiN_on_Glass_30KV_2750_nm_10.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_11.cas ha sido abierto!
# 3.8313400745391846
# TiN_on_Glass_30KV_2750_nm_11.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_12.cas ha sido abierto!
# 3.9078166484832764
# TiN_on_Glass_30KV_2750_nm_12.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_13.cas ha sido abierto!
# 3.9335062503814697
# TiN_on_Glass_30KV_2750_nm_13.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_14.cas ha sido abierto!
# 3.889134645462036
# TiN_on_Glass_30KV_2750_nm_14.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_15.cas ha sido abierto!
# 3.911240577697754
# TiN_on_Glass_30KV_2750_nm_15.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_2.cas ha sido abierto!
# 3.8651554584503174
# TiN_on_Glass_30KV_2750_nm_2.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_3.cas ha sido abierto!
# 3.8981821537017822
# TiN_on_Glass_30KV_2750_nm_3.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_4.cas ha sido abierto!
# 3.8565800189971924
# TiN_on_Glass_30KV_2750_nm_4.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_5.cas ha sido abierto!
# 3.923771381378174
# TiN_on_Glass_30KV_2750_nm_5.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_6.cas ha sido abierto!
# 3.8665406703948975
# TiN_on_Glass_30KV_2750_nm_6.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_7.cas ha sido abierto!
# 3.830542802810669
# TiN_on_Glass_30KV_2750_nm_7.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_8.cas ha sido abierto!
# 3.8377747535705566
# TiN_on_Glass_30KV_2750_nm_8.cas Done!
# el archivo TiN_on_Glass_30KV_2750_nm_9.cas ha sido abierto!
# 3.8665010929107666
# TiN_on_Glass_30KV_2750_nm_9.cas Done!
# Los archivos .dat estan listos, la operación tardo 727.3225173950195 segundos, 12.12204195658366 minutos o 0.20203403260972766 horas.

# %% [markdown]
# # data

# %%
import os 
import re #regular expression
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
#path='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Glass\\Estabilidad'
#path='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Silicon'
files=os.listdir(path)
files_dat =[]
files_dat = [f for f in files if f[-4:] == '.dat']
dunsort=[]
Tika=[]
Nka=[]
Sika=[]
energy=[]
times=[]
thickness=[]
for s in files_dat:
    newstr = ''.join((ch if ch in '0123456789-' else ' ') for ch in s)#toma los numeros del nombre del archivo
    listOfNumbers = [int(i) for i in newstr.split()]#ubica los números dentro de un diccionario
    energy.append(listOfNumbers[0])
    thickness.append(listOfNumbers[1])
    times.append(listOfNumbers[-1])
    f = open(path+'\\'+s,'r')
    text = f.read()
    x=re.findall('ABS: (\d+....|\d+|\d+.|\d+..|\d+...)|(Ti|N|Si)',text)
    print(x)
    dunsort.append(x)
    #print(len(x),listOfNumbers[0],listOfNumbers[1])
    Tika.append(float(x[1][0]))
    c=-1
    vSi=0
    for j in x:
        c=c+1
        if j[1]=='Si':
            vSi=float(x[c+1][0])
            break
        else:
            continue
        
    if vSi==0.0:
        Sika.append(0.0)
    else:
        if vSi > 0.0000001:
            Sika.append(vSi)
        else:
            Sika.append(0.0)
# Out:
# [('', 'Ti'), ('585.952', ''), ('184.988', ''), ('', 'N'), ('348.522', ''), ('0.026', ''), ('', 'Si'), ('6.182', ''), ('0.113', ''), ('0.014', ''), ('0.391', ''), ('', 'N'), ('0.225', ''), ('0.177', ''), ('0.012', '')]
# [('', 'Ti'), ('584.149', ''), ('184.003', ''), ('', 'N'), ('346.21', ''), ('0.029', ''), ('', 'Si'), ('6.787', ''), ('0.123', ''), ('0.016', ''), ('0.429', ''), ('', 'N'), ('0.247', ''), ('0.194', ''), ('0.013', '')]
# [('', 'Ti'), ('584.297', ''), ('182.52', ''), ('', 'N'), ('345.081', ''), ('0.028', ''), ('', 'Si'), ('6.554', ''), ('0.123', ''), ('0.015', ''), ('0.413', ''), ('', 'N'), ('0.238', ''), ('0.187', ''), ('0.013', '')]
# [('', 'Ti'), ('585.264', ''), ('183.926', ''), ('', 'N'), ('346.891', ''), ('0.028', ''), ('', 'Si'), ('6.428', ''), ('0.114', ''), ('0.015', ''), ('0.407', ''), ('', 'N'), ('0.235', ''), ('0.184', ''), ('0.012', '')]
# [('', 'Ti'), ('584.712', ''), ('183.151', ''), ('', 'N'), ('345.934', ''), ('0.026', ''), ('', 'Si'), ('6.223', ''), ('0.111', ''), ('0.014', ''), ('0.393', ''), ('', 'N'), ('0.226', ''), ('0.178', ''), ('0.012', '')]
# [('', 'Ti'), ('586.263', ''), ('182.386', ''), ('', 'N'), ('345.491', ''), ('0.029', ''), ('', 'Si'), ('6.862', ''), ('0.130', ''), ('0.016', ''), ('0.431', ''), ('', 'N'), ('0.248', ''), ('0.196', ''), ('0.013', '')]
# [('', 'Ti'), ('586.305', ''), ('184.423', ''), ('', 'N'), ('347.713', ''), ('0.028', ''), ('', 'Si'), ('6.605', ''), ('0.120', ''), ('0.015', ''), ('0.416', ''), ('', 'N'), ('0.240', ''), ('0.189', ''), ('0.012', '')]
# [('', 'Ti'), ('585.328', ''), ('184.208', ''), ('', 'N'), ('347.345', ''), ('0.028', ''), ('', 'Si'), ('6.602', ''), ('0.129', ''), ('0.015', ''), ('0.415', ''), ('', 'N'), ('0.239', ''), ('0.188', ''), ('0.013', '')]
# [('', 'Ti'), ('584.883', ''), ('182.994', ''), ('', 'N'), ('345.461', ''), ('0.029', ''), ('', 'Si'), ('6.677', ''), ('0.108', ''), ('0.016', ''), ('0.426', ''), ('', 'N'), ('0.246', ''), ('0.192', ''), ('0.012', '')]
# [('', 'Ti'), ('585.937', ''), ('183.2', ''), ('', 'N'), ('346.111', ''), ('0.029', ''), ('', 'Si'), ('6.560', ''), ('0.115', ''), ('0.016', ''), ('0.417', ''), ('', 'N'), ('0.241', ''), ('0.188', ''), ('0.012', '')]
# [('', 'Ti'), ('585.535', ''), ('183.229', ''), ('', 'N'), ('346.446', ''), ('0.029', ''), ('', 'Si'), ('6.783', ''), ('0.128', ''), ('0.016', ''), ('0.427', ''), ('', 'N'), ('0.245', ''), ('0.194', ''), ('0.013', '')]
# [('', 'Ti'), ('585.346', ''), ('183.859', ''), ('', 'N'), ('347.133', ''), ('0.027', ''), ('', 'Si'), ('6.444', ''), ('0.110', ''), ('0.015', ''), ('0.406', ''), ('', 'N'), ('0.233', ''), ('0.184', ''), ('0.012', '')]
# [('', 'Ti'), ('585.214', ''), ('183.835', ''), ('', 'N'), ('346.726', ''), ('0.029', ''), ('', 'Si'), ('6.716', ''), ('0.120', ''), ('0.016', ''), ('0.425', ''), ('', 'N'), ('0.245', ''), ('0.192', ''), ('0.013', '')]
# [('', 'Ti'), ('585.619', ''), ('183.48', ''), ('', 'N'), ('347.118', ''), ('0.026', ''), ('', 'Si'), ('6.195', ''), ('0.113', ''), ('0.014', ''), ('0.391', ''), ('', 'N'), ('0.225', ''), ('0.177', ''), ('0.012', '')]
# [('', 'Ti'), ('583.784', ''), ('183.003', ''), ('', 'N'), ('345.837', ''), ('0.026', ''), ('', 'Si'), ('5.996', ''), ('0.108', ''), ('0.014', ''), ('0.379', ''), ('', 'N'), ('0.219', ''), ('0.172', ''), ('0.011', '')]
# [('', 'Ti'), ('585.15', ''), ('183.434', ''), ('', 'N'), ('346.692', ''), ('0.028', ''), ('', 'Si'), ('6.595', ''), ('0.125', ''), ('0.015', ''), ('0.415', ''), ('', 'N'), ('0.239', ''), ('0.188', ''), ('0.013', '')]
# [('', 'Ti'), ('586.778', ''), ('185.207', ''), ('', 'N'), ('351.807', ''), ('0.001', ''), ('', 'Si'), ('0.699', ''), ('0.003', ''), ('0.001', ''), ('0.044', ''), ('', 'N'), ('0.024', ''), ('0.020', ''), ('0.000', '')]
# [('', 'Ti'), ('586.146', ''), ('183.479', ''), ('', 'N'), ('348.976', ''), ('0.001', ''), ('', 'Si'), ('0.636', ''), ('0.004', ''), ('0.001', ''), ('0.041', ''), ('', 'N'), ('0.022', ''), ('0.018', ''), ('0.000', '')]
# [('', 'Ti'), ('585.301', ''), ('182.657', ''), ('', 'N'), ('348.001', ''), ('0.001', ''), ('', 'Si'), ('0.707', ''), ('0.007', ''), ('0.001', ''), ('0.045', ''), ('', 'N'), ('0.024', ''), ('0.020', ''), ('0.000', '')]
# [('', 'Ti'), ('586.676', ''), ('182.849', ''), ('', 'N'), ('348.83', ''), ('0.001', ''), ('', 'Si'), ('0.943', ''), ('0.008', ''), ('0.002', ''), ('0.059', ''), ('', 'N'), ('0.031', ''), ('0.027', ''), ('0.001', '')]
# [('', 'Ti'), ('586.179', ''), ('184.636', ''), ('', 'N'), ('350.604', ''), ('0.001', ''), ('', 'Si'), ('0.683', ''), ('0.007', ''), ('0.001', ''), ('0.043', ''), ('', 'N'), ('0.023', ''), ('0.020', ''), ('0.000', '')]
# [('', 'Ti'), ('586.299', ''), ('184.224', ''), ('', 'N'), ('350.299', ''), ('0.001', ''), ('', 'Si'), ('0.698', ''), ('0.005', ''), ('0.002', ''), ('0.045', ''), ('', 'N'), ('0.025', ''), ('0.020', ''), ('0.000', '')]
# [('', 'Ti'), ('586.86', ''), ('183.094', ''), ('', 'N'), ('349.454', ''), ('0.001', ''), ('', 'Si'), ('0.817', ''), ('0.007', ''), ('0.002', ''), ('0.051', ''), ('', 'N'), ('0.027', ''), ('0.023', ''), ('0.000', '')]
# [('', 'Ti'), ('584.352', ''), ('183.612', ''), ('', 'N'), ('348.195', ''), ('0.001', ''), ('', 'Si'), ('0.748', ''), ('0.007', ''), ('0.002', ''), ('0.047', ''), ('', 'N'), ('0.025', ''), ('0.021', ''), ('0.000', '')]
# [('', 'Ti'), ('584.479', ''), ('183.594', ''), ('', 'N'), ('348.286', ''), ('0.001', ''), ('', 'Si'), ('0.910', ''), ('0.009', ''), ('0.002', ''), ('0.056', ''), ('', 'N'), ('0.030', ''), ('0.026', ''), ('0.001', '')]
# [('', 'Ti'), ('586.104', ''), ('184.608', ''), ('', 'N'), ('350.828', ''), ('0.001', ''), ('', 'Si'), ('0.589', ''), ('0.004', ''), ('0.001', ''), ('0.038', ''), ('', 'N'), ('0.020', ''), ('0.017', ''), ('0.000', '')]
# [('', 'Ti'), ('586.699', ''), ('185.085', ''), ('', 'N'), ('350.613', ''), ('0.001', ''), ('', 'Si'), ('0.905', ''), ('0.009', ''), ('0.002', ''), ('0.056', ''), ('', 'N'), ('0.030', ''), ('0.026', ''), ('0.001', '')]
# [('', 'Ti'), ('586.114', ''), ('183.209', ''), ('', 'N'), ('349.315', ''), ('0.001', ''), ('', 'Si'), ('0.830', ''), ('0.008', ''), ('0.002', ''), ('0.051', ''), ('', 'N'), ('0.027', ''), ('0.024', ''), ('0.001', '')]
# [('', 'Ti'), ('586.235', ''), ('182.793', ''), ('', 'N'), ('348.718', ''), ('0.001', ''), ('', 'Si'), ('0.889', ''), ('0.007', ''), ('0.002', ''), ('0.054', ''), ('', 'N'), ('0.029', ''), ('0.025', ''), ('0.001', '')]
# [('', 'Ti'), ('584.729', ''), ('183.666', ''), ('', 'N'), ('348.765', ''), ('0.001', ''), ('', 'Si'), ('0.839', ''), ('0.008', ''), ('0.002', ''), ('0.052', ''), ('', 'N'), ('0.028', ''), ('0.024', ''), ('0.001', '')]
# [('', 'Ti'), ('586.024', ''), ('183.745', ''), ('', 'N'), ('349.181', ''), ('0.001', ''), ('', 'Si'), ('0.622', ''), ('0.004', ''), ('0.001', ''), ('0.039', ''), ('', 'N'), ('0.021', ''), ('0.018', ''), ('0.000', '')]
# [('', 'Ti'), ('586.298', ''), ('184.784', ''), ('', 'N'), ('350.571', ''), ('0.001', ''), ('', 'Si'), ('0.821', ''), ('0.005', ''), ('0.002', ''), ('0.052', ''), ('', 'N'), ('0.028', ''), ('0.024', ''), ('0.000', '')]
# [('', 'Ti'), ('1834.61', ''), ('156.682', ''), ('', 'N'), ('373.981', ''), ('2.185', ''), ('', 'Si'), ('2.434', ''), ('0.231', ''), ('0.000', ''), ('0.058', ''), ('', 'N'), ('0.013', ''), ('0.047', ''), ('0.017', '')]
# [('', 'Ti'), ('6776.62', ''), ('83.094', ''), ('', 'N'), ('245.03', ''), ('3.117', ''), ('', 'Si'), ('8.871', ''), ('13.303', ''), ('1.443', ''), ('0.012', ''), ('', 'N'), ('0.000', ''), ('0.056', ''), ('0.689', '')]
# [('', 'Ti'), ('6800.92', ''), ('85.360', ''), ('', 'N'), ('249.954', ''), ('3.023', ''), ('', 'Si'), ('8.608', ''), ('12.893', ''), ('1.415', ''), ('0.012', ''), ('', 'N'), ('0.000', ''), ('0.054', ''), ('0.668', '')]
# [('', 'Ti'), ('6813.85', ''), ('84.861', ''), ('', 'N'), ('249.192', ''), ('3.119', ''), ('', 'Si'), ('8.681', ''), ('12.944', ''), ('1.469', ''), ('0.012', ''), ('', 'N'), ('0.000', ''), ('0.054', ''), ('0.671', '')]
# [('', 'Ti'), ('6803.05', ''), ('82.653', ''), ('', 'N'), ('245.294', ''), ('3.078', ''), ('', 'Si'), ('8.658', ''), ('12.925', ''), ('1.441', ''), ('0.012', ''), ('', 'N'), ('0.000', ''), ('0.054', ''), ('0.670', '')]
# [('', 'Ti'), ('6805.56', ''), ('84.670', ''), ('', 'N'), ('249.221', ''), ('3.032', ''), ('', 'Si'), ('8.606', ''), ('12.841', ''), ('1.428', ''), ('0.012', ''), ('', 'N'), ('0.000', ''), ('0.054', ''), ('0.666', '')]
# [('', 'Ti'), ('6791.46', ''), ('83.654', ''), ('', 'N'), ('245.415', ''), ('3.154', ''), ('', 'Si'), ('9.120', ''), ('13.729', ''), ('1.467', ''), ('0.012', ''), ('', 'N'), ('0.000', ''), ('0.057', ''), ('0.711', '')]
# [('', 'Ti'), ('6818.85', ''), ('84.329', ''), ('', 'N'), ('248.521', ''), ('2.935', ''), ('', 'Si'), ('8.277', ''), ('12.450', ''), ('1.388', ''), ('0.011', ''), ('', 'N'), ('0.000', ''), ('0.052', ''), ('0.644', '')]

# %%
len(Sika)
# Out:
# 96

# %%
dic_data={'Energy':energy,'Thickness':thickness,'Tika':Tika,'Sika':Sika,'Times':times}
df=pd.DataFrame(dic_data)
df['I_ratio']=df.Sika/df.Tika
df.head(30)
# Out:
#     Energy  Thickness     Tika   Sika  Times   I_ratio
# 0       10        440  585.952  6.182      0  0.010550
# 1       10        440  584.149  6.787      1  0.011619
# 2       10        440  584.297  6.554     10  0.011217
# 3       10        440  585.264  6.428     11  0.010983
# 4       10        440  584.712  6.223     12  0.010643
# 5       10        440  586.263  6.862     13  0.011705
# 6       10        440  586.305  6.605     14  0.011265
# 7       10        440  585.328  6.602     15  0.011279
# 8       10        440  584.883  6.677      2  0.011416
# 9       10        440  585.937  6.560      3  0.011196
# 10      10        440  585.535  6.783      4  0.011584
# 11      10        440  585.346  6.444      5  0.011009
# 12      10        440  585.214  6.716      6  0.011476
# 13      10        440  585.619  6.195      7  0.010579
# 14      10        440  583.784  5.996      8  0.010271
# 15      10        440  585.150  6.595      9  0.011271
# 16      10        520  586.778  0.699      0  0.001191
# 17      10        520  586.146  0.636      1  0.001085
# 18      10        520  585.301  0.707     10  0.001208
# 19      10        520  586.676  0.943     11  0.001607
# 20      10        520  586.179  0.683     12  0.001165
# 21      10        520  586.299  0.698     13  0.001191
# 22      10        520  586.860  0.817     14  0.001392
# 23      10        520  584.352  0.748     15  0.001280
# 24      10        520  584.479  0.910      2  0.001557
# 25      10        520  586.104  0.589      3  0.001005
# 26      10        520  586.699  0.905      4  0.001543
# 27      10        520  586.114  0.830      5  0.001416
# 28      10        520  586.235  0.889      6  0.001516
# 29      10        520  584.729  0.839      7  0.001435

# %%
espesoresd = {10:espesores[0],
 15:espesores[1],
 20:espesores[2],
 25:espesores[3],
 30:espesores[4]}

dica={}
thc0=[]
en0=[]
avg0=[]
std0=[]
Tiavg=[]
Tistd=[]
Feavg=[]
Festd=[]
nnn=0
for i in espesoresd:
    for j in espesoresd[i]:
        Iavg = df[(df.Thickness==j) & (df.Energy==i)].sort_values('Times').I_ratio.mean()
        Istdd = df[(df.Thickness==j) & (df.Energy==i)].sort_values('Times').I_ratio.std()
        thc0.append(j)
        en0.append(i)
        avg0.append(Iavg)
        std0.append(Istdd)
dica['Energy'] = en0
dica['Thickness'] = thc0
dica['I_Avg'] = avg0
dica['I_Std'] = std0

# %%
dfstb=pd.DataFrame(dica)
dfstb['Pstd']=dfstb.I_Std/dfstb.I_Avg*100
#dfstb['Si_Pstd']=dfstb.Sistd/dfstb.Siavg*100
#dfstb['Ti_Pstd']=dfstb.Tistd/dfstb.Tiavg*100
dfaux=dfstb.set_index(['Energy','Thickness'])
#plt.plot(dfstb[dfstb.Energy==10].Thickness,dfstb[dfstb.Energy==10].Pstd,'r*')
#dfaux.to_excel(path+'\\'+'Corregido_Desv_TiN_on_Glass.xlsx')
dfstb
# Out:
#    Energy  Thickness     I_Avg     I_Std       Pstd
# 0      10        440  0.011129  0.000424   3.812854
# 1      10        520  0.001316  0.000192  14.598145
# 2      15       1000  0.001405  0.000114   8.092911
# 3      20       1600  0.001021  0.000062   6.109601
# 4      25       2180  0.001209  0.000046   3.826476
# 5      30       2750  0.001268  0.000039   3.067665

# %%
for i in espesores:
    plt.plot(dfstb[dfstb.Energy==i].Thickness,dfstb[dfstb.Energy==i].Pstd,'-*',label=i)
    #plt.yscale('log')
    plt.ylabel('Desv estandar %')
    plt.xlabel('Thickness')
    plt.legend()
plt.title('Glass desviaciones estandar')
plt.rcParams["figure.figsize"] = (8,6)
plt.savefig('Glass_stddev.jpg',format='jpg',dpi=300)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-2a8c616b4faa> in <module>
#       1 for i in espesores:
# ----> 2     plt.plot(dfstb[dfstb.Energy==i].Thickness,dfstb[dfstb.Energy==i].Pstd,'-*',label=i)
#       3     #plt.yscale('log')
#       4     plt.ylabel('Desv estandar %')
#       5     plt.xlabel('Thickness')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     232         #  The ambiguous case is object-dtype.  See GH#27803
#     233         if len(lvalues) != len(rvalues):
# --> 234             raise ValueError("Lengths must match to compare")
#     235
#     236     if should_extension_dispatch(lvalues, rvalues):
#
# ValueError: Lengths must match to compare
