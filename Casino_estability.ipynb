# %%
import os 
import pandas as pd 

path='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Testing estability'
files=os.listdir(path)

# %% [markdown]
# # Se busca estandarizar la lectura de los datos de intensidad de rayos x dados por el software CASINO,
# ### La lectura de los datos con formato .dat resultan muy poco cómodos para hacer el análisis
# ### Como primer acercamiento a la lectura de estos datos, no se logró el objetivo. Continua planteada la posibilidad

# %%
files_dat = [f for f in files if f[-4:] == '.dat']
files_dat
# Out:
# ['TiN_Si_30kv_330_1.dat',
#  'TiN_Si_30kv_330_10.dat',
#  'TiN_Si_30kv_330_2.dat',
#  'TiN_Si_30kv_330_3.dat',
#  'TiN_Si_30kv_330_4.dat',
#  'TiN_Si_30kv_330_5.dat',
#  'TiN_Si_30kv_330_7.dat',
#  'TiN_Si_30kv_330_8.dat',
#  'TiN_Si_30kv_330_9.dat']

# %%
import csv

datContent =[i.strip().split() for i in open(path+'\\'+'TiN_Si_30kv_330_1.dat').readlines()] # the methods strip and split, are used to fix the data

with open(path+'\\'+'TiN_Si_30kv_330_1.csv', 'w') as f1:
    writer = csv.writer(f1)
    writer.writerows(datContent)

# %%
a='hola mundo bello '
c=a.strip()
a
c
# Out:
# 'hola mundo bello'

# %%
datos=[]
for i in datContent:
    if len(i)==4 or (len(i)==3 and i[0]=='PRZ'):
        datos.append(i)
        print(i)
        print(len(i))
    else:
        continue
# Out:
# ['PRZ', 'of', 'Ti', [0, 0]]
# 4
# ['Ka1:', '886.317', 'ABS:', '874.674']
# 4
# ['La1:', '175.954', 'ABS:', '65.3556']
# 4
# ['PRZ', 'of', 'N', [0, 0]]
# 4
# ['Ka1:', '201.728', 'ABS:', '122.258']
# 4
# ['PRZ', 'of', 'Si', [0, 0]]
# 4
# ['Ka1:', '13295.2', 'ABS:', '7175.69']
# 4

# %%
datos
# Out:
# [['PRZ', 'of', 'Ti', [0, 0]],
#  ['Ka1:', '886.317', 'ABS:', '874.674'],
#  ['La1:', '175.954', 'ABS:', '65.3556'],
#  ['PRZ', 'of', 'N', [0, 0]],
#  ['Ka1:', '201.728', 'ABS:', '122.258'],
#  ['PRZ', 'of', 'Si', [0, 0]],
#  ['Ka1:', '13295.2', 'ABS:', '7175.69']]

# %%
df = pd.DataFrame()

# %%
df=df.append(datos)
df
# Out:
#       0        1     2        3
# 0   PRZ       of    Ti   [0, 0]
# 1  Ka1:  886.317  ABS:  874.674
# 2  La1:  175.954  ABS:  65.3556
# 3   PRZ       of     N   [0, 0]
# 4  Ka1:  201.728  ABS:  122.258
# 5   PRZ       of    Si   [0, 0]
# 6  Ka1:  13295.2  ABS:  7175.69
# 0   PRZ       of    Ti   [0, 0]
# 1  Ka1:  886.317  ABS:  874.674
# 2  La1:  175.954  ABS:  65.3556
# 3   PRZ       of     N   [0, 0]
# 4  Ka1:  201.728  ABS:  122.258
# 5   PRZ       of    Si   [0, 0]
# 6  Ka1:  13295.2  ABS:  7175.69
# 0   PRZ       of    Ti   [0, 0]
# 1  Ka1:  886.317  ABS:  874.674
# 2  La1:  175.954  ABS:  65.3556
# 3   PRZ       of     N   [0, 0]
# 4  Ka1:  201.728  ABS:  122.258
# 5   PRZ       of    Si   [0, 0]
# 6  Ka1:  13295.2  ABS:  7175.69
# 0   PRZ       of    Ti   [0, 0]
# 1  Ka1:  886.317  ABS:  874.674
# 2  La1:  175.954  ABS:  65.3556
# 3   PRZ       of     N   [0, 0]
# 4  Ka1:  201.728  ABS:  122.258
# 5   PRZ       of    Si   [0, 0]
# 6  Ka1:  13295.2  ABS:  7175.69
# ...

# %%
df = pd.DataFrame()
dfp = pd.DataFrame()

# %%
dfp[2][5]
# Out:
# 5    1.2828
# 5    1.2828
# Name: 2, dtype: object

# %%
dfp=dfp.append(datContent)

# %%
for i in dfp.columns:
    dfp[i].astype('str').apply(lambda x: print(dfp[i].name) if x.startswith('ABS') else 'pass')
# Out:
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 2
# 5
# 5
# 5
# 5
# 5
# 5
# 10
# 10

# %%
for f in files_dat:
    data = pd.read_csv(path+'\\'+'TiN_Si_30kv_330_1.csv', sep='delimiter', header=4)
    df = df.append(data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
df.head(10)
# Out:
#      0 0,1.28397,1.2828,1.41217,1.30427           PRZ       Ti       of  \
# 0  NaN                              NaN  Intensities:      NaN      NaN
# 1  NaN                              NaN           PRZ        N       of
# 2  NaN                              NaN  Intensities:      NaN      NaN
# 3  NaN                              NaN             0   1.3653  1.41623
# 4  NaN                              NaN       19.8477  1.45521  1.59454
# 5  NaN                              NaN       39.6953  1.42888  1.66166
# 6  NaN                              NaN        59.543  1.40573   1.7372
# 7  NaN                              NaN       79.3907  1.37006  1.79704
# 8  NaN                              NaN       99.2383  1.33007  1.85378
# 9  NaN                              NaN       119.086  1.26895  1.87822
#
#   Depth(nm),Intensity:,K,Intensity,K,ABS,Intensity:,LIII,Intensity:,LIII,ABS
# 0                                                NaN
# ...

# %%
df=df.dropna()

# %%
df
# Out:
# Empty DataFrame
# Columns: [PRZ of Ti, Unnamed: 0, -----------------------------------------------------------------, Unnamed: 2]
# Index: []

# %%
dfp=pd.DataFrame()

# %%
data=pd.read_table(path+'\\'+f,error_bad_lines=False)
data

# %%
datan=pd.read_table(path+'\\'+'TiN_Si_30kv_330_1.dat',' ')
datan
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-23-5f2fa2bf5c70> in <module>
# ----> 1 datan=pd.read_table(path+'\\'+'TiN_Si_30kv_330_1.dat',' ')
#       2 datan
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-7c4522ad90c5> in <module>
# ----> 1 datan
#
# NameError: name 'datan' is not defined
