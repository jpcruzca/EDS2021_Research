# %% [markdown]
# # To gather two excel files in a unique DataFrame

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
path1='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Silicon\\Si_lowKV\\Matrix_TiN_on_Si_lowKV.xlsx'
path2='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Silicon\\Matrix_TiN_on_Si.xlsx'

# %%
df1=pd.read_excel(path1,index_col=[1,0])#inf  
df2=pd.read_excel(path2,index_col=[0,1])

# %%
df1
# Out:
#                      Tika     Sika      Nka       I_ratio
# Thickness Energy
# 20        5         0.024  461.565   34.789  19231.875000
# 40        5         0.024  302.111   77.898  12587.958333
# 60        5         0.024  163.484  121.613   6811.833333
# 80        5         0.024   73.665  154.511   3069.375000
# 100       5         0.024   24.927  178.214   1038.625000
# ...                   ...      ...      ...           ...
# 4200      9       396.179    0.000  330.871      0.000000
# 4400      9       396.144    0.000  332.139      0.000000
# 4600      9       396.047    0.000  330.855      0.000000
# 4800      9       396.136    0.000  330.154      0.000000
# 5000      9       395.674    0.000  330.182      0.000000
#
# [330 rows x 4 columns]

# %%
frames=[df1,df2]

# %%
df3=pd.concat(frames)

# %%
# Out:
#                       Tika     Sika      Nka       I_ratio
# Thickness Energy
# 20        5          0.024  461.565   34.789  19231.875000
# 40        5          0.024  302.111   77.898  12587.958333
# 60        5          0.024  163.484  121.613   6811.833333
# 80        5          0.024   73.665  154.511   3069.375000
# 100       5          0.024   24.927  178.214   1038.625000
# ...                    ...      ...      ...           ...
# 5000      26      5489.010    0.000  283.177      0.000000
#           27      5852.750    0.000  271.027      0.000000
#           28      6211.420    0.000  267.093      0.000000
#           29      6578.620    0.000  252.658      0.000000
#           30      6911.910    0.000  246.834      0.000000
#
# [1715 rows x 4 columns]

# %%
for i in range(0,10):
    plt.plot(df3.loc[20+i*20,:].I_ratio,'*',label=f'{20+i*20}')
    #plt.ylim(0,400)
    plt.xlim(4,15)
    plt.yscale('log')
#plt.legend()
plt.show()
