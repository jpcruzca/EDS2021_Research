# %%
import os 
import re #regular expression
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pathSi='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Silicon\\Si_lowKV\\Fit_params_TiN_on_Si_ADD_lowKV.xlsx'
pathGlass='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\Glass\\GlasslowKV\\Fit_params_TiN_on_Glass_addlowKV.xlsx'
pathSS='C:\\Users\\Juan Pablo Nicolás\\Documents\\FISICA\\FISICA ESTUDIO\\MICROSCOPIA ELECTRONICA\\paper ecuacion Ene2021\\Sim_batch\\Matrix Simulation\\SS\\Fit_params_TiN_on_SS_higthkV.xlsx'

# %%
dfSi=pd.read_excel(pathSi)
dfGlass=pd.read_excel(pathGlass)
dfSS=pd.read_excel(pathSS)

# %%
plt.plot(dfSi.Energy-1.740,dfSi.beta,'r*',label='Si')
plt.plot(dfGlass.Energy-1.740,dfGlass.beta,'b*',label='Glass')
plt.plot(dfSS.Energy-6.405,dfSS.beta,'g*',label='SS')
plt.ylim(0.5e0,3e0)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy-Ec-EcTi')
plt.legend()

# %%
plt.plot(dfSi.Energy-1.740-(4.512+4.933)/2,dfSi.beta,'r*',label='Si')
plt.plot(dfGlass.Energy-1.740-(4.512+4.933)/2,dfGlass.beta,'b*',label='Glass')
plt.plot(dfSS.Energy-6.405-(4.512+4.933)/2,dfSS.beta,'g*',label='SS')
#plt.ylim(1e-1,1e1)
plt.ylim(0.5e0,3e0)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy-Ec-EcTi')
plt.legend()

# %%
plt.plot(dfSi.Energy-1.740-(4.512+4.933)/2,dfSi.n,'r*')
plt.plot(dfGlass.Energy-1.740-(4.512+4.933)/2,dfGlass.n,'b*')
plt.plot(dfSS.Energy-6.405-(4.512+4.933)/2,dfSS.n,'g*')
plt.title('n')
plt.ylim(2.5e-0,5e0)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy-Ec-EcTi')
# Out:
# Text(0.5, 0, 'Energy-Ec-EcTi')

# %%
plt.plot(dfSi.Energy-1.740,dfSi.n,'r*')
plt.plot(dfGlass.Energy-1.740,dfGlass.n,'b*')
plt.plot(dfSS.Energy-6.405,dfSS.n,'g*')
plt.title('n')
plt.ylim(2.5e-0,5e0)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy-Ec-EcTi')
# Out:
# Text(0.5, 0, 'Energy-Ec-EcTi')
